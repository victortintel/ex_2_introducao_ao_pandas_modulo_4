# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
df_mat_total = df_mat/24
df_por_total = df_por/18
df_geo_total = df_geo/8
df_ing_total = df_ing/8
df_his_total = df_his/8
df_fis_total = df_fis/12
df_qui_total = df_qui/12
print("Matemática: ")
print(df_mat_total)
print("Português: ")
print(df_por_total)
print("Geografia: ")
print(df_geo_total)
print("Inglês: ")
print(df_ing)
print("História: ")
print(df_his_total)
print("Física: ")
print(df_fis_total)
print("Química: ")
print(df_qui_total)
# Out:
# Matemática:
#     Qt_acertos
# 0     0.250000
# 1     0.791667
# 2     0.583333
# 3     0.416667
# 4     0.291667
# ..         ...
# 95    0.250000
# 96    0.333333
# 97    0.958333
# 98    0.000000
# 99    0.458333
#
# [100 rows x 1 columns]
# Português:
#     Qt_acertos
# 0     0.388889
# 1     0.555556
# 2     0.888889
# 3     0.388889
# 4     0.111111
# ..         ...
# 95    0.222222
# 96    0.055556
# 97    0.277778
# 98    0.555556
# 99    0.833333
#
# [100 rows x 1 columns]
# Geografia:
#     Qt_acertos
# 0        0.875
# 1        0.000
# 2        0.000
# 3        0.375
# 4        0.250
# ..         ...
# 95       0.875
# 96       0.500
# 97       0.000
# 98       0.375
# 99       0.000
#
# [100 rows x 1 columns]
# Inglês:
#     Qt_acertos
# 0            3
# 1            0
# 2            5
# 3            4
# 4            7
# ..         ...
# 95           1
# 96           6
# 97           2
# 98           1
# 99           1
#
# [100 rows x 1 columns]
# História:
# ...

# %%
# 2) Seu código aqui
df_total_acertos = df_qui + df_fis + df_his + df_ing + df_geo + df_por + df_mat
print("O total de acertos de cada aluno: ")
print(df_total_acertos)
# Out:
# O total de acertos de cada aluno:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
df_perc_geral = df_total_acertos/90
df_perc_geral
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
df_perc_geral
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui

df_perc_geral["Aprovado"] = 0
df_perc_geral.loc[df_perc_geral["Qt_acertos"] >= 0.45, "Aprovado"] = 1
alunos_acima = df_perc_geral["Aprovado"].sum()
print(f"{alunos_acima} alunos tiveram nota maior que 45.")
# Out:
# 47 alunos tiveram nota maior que 45.

# %%
alunos_acima
# Out:
# 47

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# QUESTÃO 1: 
coluna_mat = "desqualificados em mat"
coluna_fis = "desqualificados em fis"
coluna_quim = "desqualificados em quim"

df = pd.DataFrame(
                index=["N. de Alunos"],
                 columns=[coluna_mat, coluna_fis, coluna_quim])
df.iloc[0,0] = 3
df.iloc[0,1] = 12
df.iloc[0,2] = 9
df
# Out:
#              desqualificados em mat desqualificados em fis  \
# N. de Alunos                      3                     12
#
#              desqualificados em quim
# N. de Alunos                       9

# %%
# QUESTÃO 2: Quantos são esses alunos?
num_total = df["desqualificados em mat"] + df["desqualificados em fis"] + df["desqualificados em quim"]
num_total
# Out:
# N. de Alunos    24
# dtype: object

# %%
#QUESTÃO 3: Qual a média desses alunos em história e geografia?
media_hist_desclassificados = df_his[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)].mean()
media_hist_desclassificados
# Out:
# Qt_acertos    3.434783
# dtype: float64

# %%
media_geo_desclassificados = df_geo[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)].mean()
media_geo_desclassificados
# Out:
# Qt_acertos    3.217391
# dtype: float64

# %%
#QUESTÃO 4: Monte um DataFrame com os alunos que passaram para a segunda fase.
#Repare que estes alunos não podem ter sido desqualificados

alunos_aprovados = {
    "Alunos Aprovados": 47
}

pd.DataFrame({"Total": alunos_aprovados})
# Out:
#                   Total
# Alunos Aprovados     47

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
# 1) Sua solução aqui
vac_acre = pd.read_csv('vacinacoes_ac.csv', sep=";")
vac_acre
# Out:
#                                  document_id  \
# 0  592e8230-4dec-4285-9ca6-a2e0b13c8ce6-i0b0
# 1  99c16a36-0eec-4c28-858c-197085b5815f-i0b0
# 2  5bcd8893-cf6e-438b-9596-264f2fa4f678-i0b0
# 3  9a137857-c8ee-480c-ac11-69f45374260e-i0b0
# 4  6395bf47-6c42-45d0-9c2f-f24a71288bd7-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  80dc9392f6870a1161545d3a5a9246206528d5e33fd68b...              27
# 1  8e8dbedd8661c6fff16a5a3207a2947453311cd5e3f2c1...              40
# 2  f90d1b4c2b20810484f3229650a3a2e7545bf11378f55b...              21
# 3  c8ed8ecd1354c9ffad0821e5315dcd26aaa4b96b009ec2...              53
# 4  d33c98f9c1a00e442ad9b75e31517fdf8b6e5f14331fa6...              48
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1994-07-10                          F                        1
# 1              1981-02-23                          F                        1
# ...

# %%
# 1)Quantas vacinas estão registradas nessa base?
vac_acre["vacina_nome"].unique()
# Out:
# array(['COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#        'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#        'COVID-19 PEDIÁTRICA - PFIZER COMIRNATY',
#        'COVID-19 PFIZER - COMIRNATY', 'COVID-19 JANSSEN - Ad26.COV2.S',
#        'COVID-19 ASTRAZENECA - ChAdOx1-S',
#        'COVID-19 PFIZER - COMIRNATY BIVALENTE',
#        'COVID-19 SINOVAC - CORONAVAC', 'INF3',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA', nan, 'VVBN'],
#       dtype=object)

# %%
# 1)Quantas vacinas estão registradas nessa base?

qnts_vacinas = vac_acre["vacina_nome"].nunique()
print(f"Foram registradas um total de {qnts_vacinas} vacinas.")
# Out:
# Foram registradas um total de 12 vacinas.

# %%
# 2) Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)

qnts_pacientes = vac_acre["document_id"].nunique()
print(f"Foram vacinados um total de {qnts_pacientes} pessoas.")
# Out:
# Foram vacinados um total de 373919 pessoas.

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose? 
#OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique().

qnts_doses = vac_acre["vacina_descricao_dose"].unique()
qnts_doses
# Out:
# array(['2ª Dose', '1ª Dose', 'Reforço', '2º Reforço', 'Dose', 'Única',
#        'Revacinação', '3º Reforço', 'Dose Adicional',
#        '4ª Dose Revacinação', '2ª Dose Revacinação', '1º Reforço',
#        '3ª Dose', '1ª Dose Revacinação', '3ª Dose Revacinação',
#        '5ª Dose Revacinação'], dtype=object)

# %%
# 3)
vac_acre["Primeira dose"] = 0
vac_acre.loc[vac_acre["vacina_descricao_dose"] == '1ª Dose', "Primeira dose"] = 1
vacinados_primeira = vac_acre["Primeira dose"].sum()
print(f"{vacinados_primeira} pessoas foram vacinadas com a primeira dose.")
# Out:
# 141249 pessoas foram vacinadas com a primeira dose.

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados?

vac_acre["menor de idade"] = 0
vac_acre.loc[vac_acre["paciente_idade"] < 18, "menor de idade"] = 1
menor_de_idade = vac_acre["menor de idade"].sum()
print(f"{menor_de_idade} pessoas são menores de idade.")
# Out:
# 70038 pessoas são menores de idade.

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre?
estabelecimentos = vac_acre["estalecimento_noFantasia"].nunique()
estabelecimentos
# Out:
# 203

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
novo_data = vac_acre[vac_acre["menor de idade"] == 1]
novo_data
# Out:
#                                       document_id  \
# 6       36dd8308-e47e-4552-8ef7-bb6eb84d23b2-i0b0
# 20      bf3b10eb-b2cb-4533-9c59-c8548f3c8c3e-i0b0
# 27      9b14c429-942f-4b23-af5d-35abd7bf0ca1-i0b0
# 31      9b42f9b6-96f4-408c-8e0d-809183d00ef4-i0b0
# 43      9bb706ea-c49a-4663-af3c-dfeeed1c04d3-i0b0
# ...                                           ...
# 373882  92184d3b-7e74-4e2d-a3d8-3c6f7aab3828-i0b0
# 373892  94189aa7-18d6-4c56-9749-ebaaa537021d-i0b0
# 373904  955b77c4-1723-41a2-8431-043d2542c887-i0b0
# 373913  9654627b-3f29-46d8-b998-be699c47eeff-i0b0
# 373917  96dc4daf-7a85-47a9-9c64-6c93a78313bb-i0b0
#
#                                               paciente_id  paciente_idade  \
# 6       da42bf4f074b02d9359c2c5328feb32951210771c64f89...               7
# 20      dab7966b3d82b4c416bdcab1ac294bc9ea1ebf817de5d7...              17
# 27      8d72b75a66192eb6ac9491c680e6b0680b59ed67824956...              13
# ...

# %%
# 2)

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.

novo_dumm = pd.get_dummies(novo_data["vacina_categoria_nome"])
novo_dumm.sum()
# Out:
# Comorbidades                                         55
# Faixa Etária                                      41656
# Gestantes                                            33
# Outros                                             3697
# Pessoas Institucionalizadas                           3
# Pessoas com Deficiência                              10
# Pessoas de 60 anos ou mais institucionalizadas        1
# População Privada de Liberdade                       51
# Povos Indígenas                                    3708
# Povos e Comunidades Tradicionais                    680
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Trabalhadores de Saúde                              238
# dtype: int64

# %%
# 4)

# %%
# 5)
